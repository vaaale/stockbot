# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
xs = np.linspace(-np.pi, np.pi, 30)
ys = np.sin(xs)
markers_on = [12, 17, 18, 19]
plt.plot(xs, ys, '-gD', markevery=markers_on)

# %%
xs = np.arange(10)
ys = np.random.rand(10, 1)

xs2 = [3,5,7]
ys2 = [ys[b] for b in xs2]

# %%
plt.plot(xs, ys)
plt.scatter(xs2, ys2, color='green', marker='o')
